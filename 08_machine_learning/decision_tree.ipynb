# %% [markdown]
# <a href="https://colab.research.google.com/github/rinviriti/AI-ML-Learning-Journey/blob/main/08_machine_learning/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Decision Tree
#
# A Decision Tree makes decisions using a tree-like structure.
#
# It is easy to understand and visualize.
#
# Decision Trees are widely used for classification and regression tasks.

# %%
from sklearn.tree import DecisionTreeClassifier

X = [[1],[2],[3],[4],[5]]
y = [0,0,0,1,1]

model = DecisionTreeClassifier()

model.fit(X,y)

print(model.predict([[4]]))
# Out:
# [1]
