# %% [markdown]
# <a href="https://colab.research.google.com/github/rinviriti/AI-ML-Learning-Journey/blob/main/08_machine_learning/ml_workflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Machine Learning Workflow
#
# Machine Learning is the process of teaching computers to learn patterns from data and make predictions or decisions without being explicitly programmed.
#
# A typical Machine Learning workflow consists of:
#
# 1. Collect Data
# 2. Clean and Prepare Data
# 3. Split Data into Training and Testing Sets
# 4. Train a Model
# 5. Evaluate Performance
# 6. Make Predictions
#
# Understanding this workflow is essential before building Machine Learning models.

# %%
steps = [
    "Collect Data",
    "Preprocess Data",
    "Split Dataset",
    "Train Model",
    "Evaluate Model",
    "Predict Results"
]

for step in steps:
    print(step)
# Out:
# Collect Data
# Preprocess Data
# Split Dataset
# Train Model
# Evaluate Model
# Predict Results
