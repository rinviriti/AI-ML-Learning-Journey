# %% [markdown]
# <a href="https://colab.research.google.com/github/rinviriti/AI-ML-Learning-Journey/blob/main/08_machine_learning/random_forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Random Forest
#
# Random Forest combines multiple decision trees to improve prediction accuracy.
#
# It is one of the most widely used Machine Learning algorithms.

# %%
from sklearn.ensemble import RandomForestClassifier

X = [[1],[2],[3],[4],[5]]
y = [0,0,0,1,1]

model = RandomForestClassifier()

model.fit(X,y)

print(model.predict([[4]]))
# Out:
# [1]
