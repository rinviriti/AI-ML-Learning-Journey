# %% [markdown]
# <a href="https://colab.research.google.com/github/rinviriti/AI-ML-Learning-Journey/blob/main/07_data_visualization/line_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Line Chart Visualization
#
# This notebook demonstrates how to create line charts using Matplotlib.

# %%
import matplotlib.pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May"]
sales = [100, 150, 200, 180, 250]

plt.plot(months, sales)

plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May"]
sales = [100, 150, 200, 180, 250]

plt.plot(months, sales, marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %% [markdown]
# ## Summary
#
# I learned how to create line charts and visualize trends over time.
