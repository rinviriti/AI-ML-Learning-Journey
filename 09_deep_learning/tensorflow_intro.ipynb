# %% [markdown]
# <a href="https://colab.research.google.com/github/rinviriti/AI-ML-Learning-Journey/blob/main/09_deep_learning/tensorflow_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to TensorFlow
#
# TensorFlow is one of the most popular Deep Learning frameworks developed by Google.
#
# It is widely used for:
#
# - Computer Vision
# - Natural Language Processing
# - Medical AI
# - Deep Learning Research
#
# TensorFlow allows us to build, train, and deploy neural networks efficiently.

# %%
import tensorflow as tf

print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.20.0

# %%
tensor = tf.constant([1, 2, 3, 4])

print(tensor)
# Out:
# tf.Tensor([1 2 3 4], shape=(4,), dtype=int32)

# %% [markdown]
# ## Summary
#
# In this notebook I learned:
#
# - What TensorFlow is
# - Why TensorFlow is important
# - How to create tensors
# - Basic TensorFlow operations
